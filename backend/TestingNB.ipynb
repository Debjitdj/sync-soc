# %%
from model import Model
from bson.objectid import ObjectId
from datetime import date, timedelta

# %%
model = Model()

# %%
model.communities.delete_many({})
model.days.delete_many({})
model.events.delete_many({})

# %%
model.add_community('the Other Society', ['pawel', 'tomek'])
model.add_community('Sync Society', ['pawel', 'tomek', 'fryderyk', 'debjit'])
model.add_community('Tomeks Society', ['tomek'])

# %%
model.assert_days_present(date(2019, 9, 30), date(2019, 10, 11))

# %%
list(model.communities.find()), list(model.days.find()), list(model.communities.find())
# Out:
# ([{'_id': ObjectId('5db5c030fbc3a0c1d24cea41'),
#    'name': 'the Other Society',
#    'mailing_list': ['pawel', 'tomek'],
#    'password': 'abc123',
#    'owner_email': 'a@a'},
#   {'_id': ObjectId('5db5c030fbc3a0c1d24cea42'),
#    'name': 'Sync Society',
#    'mailing_list': ['pawel', 'tomek', 'fryderyk', 'debjit'],
#    'password': 'abc123',
#    'owner_email': 'a@a'},
#   {'_id': ObjectId('5db5c030fbc3a0c1d24cea43'),
#    'name': 'Tomeks Society',
#    'mailing_list': ['tomek'],
#    'password': 'abc123',
#    'owner_email': 'a@a'}],
#  [{'_id': ObjectId('5db5c030fbc3a0c1d24cea44'),
#    'week_day': 0,
#    'date': '2019-09-30',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
# ...

# %%
ids = [model.get_community_id(name) for name in ['the Other Society', 'Sync Society', 'Tomeks Society']]

# %%
ids
# Out:
# [ObjectId('5db5c030fbc3a0c1d24cea41'),
#  ObjectId('5db5c030fbc3a0c1d24cea42'),
#  ObjectId('5db5c030fbc3a0c1d24cea43')]

# %%
#model.add_event(ids[1], date(2019, 10, 2), 30, 35)
model.add_event(ids[0], date(2019, 10, 2), 31, 33)
model.add_event(ids[2], date(2019, 10, 2), 32, 34)

# %%
model.add_recurring_event(ids[1], 0, 38, 41)

# %%
list(model.events.find()), list(model.days.find()), list(model.communities.find())
# Out:
# ([{'_id': ObjectId('5db5c030fbc3a0c1d24cea4f'),
#    'comm_id': ObjectId('5db5c030fbc3a0c1d24cea41'),
#    'date': '2019-10-02',
#    'start': 31,
#    'end': 33},
#   {'_id': ObjectId('5db5c030fbc3a0c1d24cea50'),
#    'comm_id': ObjectId('5db5c030fbc3a0c1d24cea43'),
#    'date': '2019-10-02',
#    'start': 32,
#    'end': 34}],
#  [{'_id': ObjectId('5db5c030fbc3a0c1d24cea44'),
#    'week_day': 0,
#    'date': '2019-09-30',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5c030fbc3a0c1d24cea45'),
#    'week_day': 1,
# ...

# %%
get_calendar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-6d28241a22e2> in <module>
# ----> 1 get_calendar()
#
# NameError: name 'get_calendar' is not defined

# %%
date('2019-01-01')
