# %%
from model import Model
from bson.objectid import ObjectId
from datetime import date, timedelta

# %%
model = Model()

# %%
model.assert_days_present(date(2019, 9, 30), date(2019, 10, 11))

# %%
list(model.communities.find()), list(model.days.find()), list(model.communities.find())
# Out:
# ([{'_id': ObjectId('5db583b03c712161122e94db'),
#    'name': 'Sync Society',
#    'mailingList': []}],
#  [{'_id': ObjectId('5db599d714649dc6374ba153'),
#    'weekDay': 5,
#    'date': '2019-11-30',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eb3'),
#    'weekDay': 0,
#    'date': '2019-09-30',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eb4'),
#    'weekDay': 1,
#    'date': '2019-10-01',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eb5'),
#    'weekDay': 2,
#    'date': '2019-10-02',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eb6'),
#    'weekDay': 3,
#    'date': '2019-10-03',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eb7'),
#    'weekDay': 4,
#    'date': '2019-10-04',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eb8'),
#    'weekDay': 5,
#    'date': '2019-10-05',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eb9'),
#    'weekDay': 6,
#    'date': '2019-10-06',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01eba'),
#    'weekDay': 0,
#    'date': '2019-10-07',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01ebb'),
#    'weekDay': 1,
#    'date': '2019-10-08',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01ebc'),
#    'weekDay': 2,
#    'date': '2019-10-09',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db59cca6b76e27ab2b01ebd'),
#    'weekDay': 3,
#    'date': '2019-10-10',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]}],
#  [{'_id': ObjectId('5db583b03c712161122e94db'),
#    'name': 'Sync Society',
#    'mailingList': []}])

# %%
list(model.communities.find()), list(model.days.find()), list(model.events.find())
# Out:
# ([{'_id': ObjectId('5db583b03c712161122e94db'),
#    'name': 'Sync Society',
#    'mailingList': []}],
#  [],
#  [])
