# %%
from model import Model
from bson.objectid import ObjectId
from datetime import date, timedelta

# %%
model = Model()

# %%
model.communities.delete_many({})
model.days.delete_many({})
model.events.delete_many({})

# %%
model.add_community('the Other Society', ['pawel', 'tomek'])
model.add_community('Sync Society', ['pawel', 'tomek', 'fryderyk', 'debjit'])
model.add_community('Fryderyks Society', ['fryderyk'])

# %%
model.assert_days_present(date(2019, 9, 30), date(2019, 10, 11))

# %%
list(model.communities.find()), list(model.days.find()), list(model.communities.find())
# Out:
# ([{'_id': ObjectId('5db5b42c8d094218d6c9da63'),
#    'name': 'the Other Society',
#    'mailing_list': ['pawel', 'tomek']},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da64'),
#    'name': 'Sync Society',
#    'mailing_list': ['pawel', 'tomek', 'fryderyk', 'debjit']},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da65'),
#    'name': 'Fryderyks Society',
#    'mailing_list': ['fryderyk']}],
#  [{'_id': ObjectId('5db5b42c8d094218d6c9da66'),
#    'week_day': 0,
#    'date': '2019-09-30',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da67'),
#    'week_day': 1,
#    'date': '2019-10-01',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da68'),
#    'week_day': 2,
#    'date': '2019-10-02',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da69'),
#    'week_day': 3,
#    'date': '2019-10-03',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6a'),
#    'week_day': 4,
#    'date': '2019-10-04',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6b'),
#    'week_day': 5,
#    'date': '2019-10-05',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6c'),
#    'week_day': 6,
#    'date': '2019-10-06',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6d'),
#    'week_day': 0,
#    'date': '2019-10-07',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6e'),
#    'week_day': 1,
#    'date': '2019-10-08',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6f'),
#    'week_day': 2,
#    'date': '2019-10-09',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da70'),
#    'week_day': 3,
#    'date': '2019-10-10',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]}],
#  [{'_id': ObjectId('5db5b42c8d094218d6c9da63'),
#    'name': 'the Other Society',
#    'mailing_list': ['pawel', 'tomek']},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da64'),
#    'name': 'Sync Society',
#    'mailing_list': ['pawel', 'tomek', 'fryderyk', 'debjit']},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da65'),
#    'name': 'Fryderyks Society',
#    'mailing_list': ['fryderyk']}])

# %%
ids = [model.get_community_id(name) for name in ['the Other Society', 'Sync Society', 'Fryderyks Society']]

# %%
ids
# Out:
# [ObjectId('5db5b42c8d094218d6c9da63'),
#  ObjectId('5db5b42c8d094218d6c9da64'),
#  ObjectId('5db5b42c8d094218d6c9da65')]

# %%
#model.add_event(ids[1], date(2019, 10, 2), 30, 35)
model.add_event(ids[0], date(2019, 10, 2), 31, 33)
model.add_event(ids[2], date(2019, 10, 2), 32, 34)

# %%
list(model.events.find()), list(model.days.find()), list(model.communities.find())
# Out:
# ([{'_id': ObjectId('5db5b42c8d094218d6c9da71'),
#    'comm_id': ObjectId('5db5b42c8d094218d6c9da63'),
#    'date': '2019-10-02',
#    'start': 31,
#    'end': 33},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da72'),
#    'comm_id': ObjectId('5db5b42c8d094218d6c9da65'),
#    'date': '2019-10-02',
#    'start': 32,
#    'end': 34}],
#  [{'_id': ObjectId('5db5b42c8d094218d6c9da66'),
#    'week_day': 0,
#    'date': '2019-09-30',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da67'),
#    'week_day': 1,
#    'date': '2019-10-01',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da68'),
#    'week_day': 2,
#    'date': '2019-10-02',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     ['5db5b42c8d094218d6c9da71'],
#     ['5db5b42c8d094218d6c9da71', '5db5b42c8d094218d6c9da72'],
#     ['5db5b42c8d094218d6c9da72'],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da69'),
#    'week_day': 3,
#    'date': '2019-10-03',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6a'),
#    'week_day': 4,
#    'date': '2019-10-04',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6b'),
#    'week_day': 5,
#    'date': '2019-10-05',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6c'),
#    'week_day': 6,
#    'date': '2019-10-06',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6d'),
#    'week_day': 0,
#    'date': '2019-10-07',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6e'),
#    'week_day': 1,
#    'date': '2019-10-08',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da6f'),
#    'week_day': 2,
#    'date': '2019-10-09',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da70'),
#    'week_day': 3,
#    'date': '2019-10-10',
#    'slots': [[],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     [],
#     []]}],
#  [{'_id': ObjectId('5db5b42c8d094218d6c9da63'),
#    'name': 'the Other Society',
#    'mailing_list': ['pawel', 'tomek']},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da64'),
#    'name': 'Sync Society',
#    'mailing_list': ['pawel', 'tomek', 'fryderyk', 'debjit']},
#   {'_id': ObjectId('5db5b42c8d094218d6c9da65'),
#    'name': 'Fryderyks Society',
#    'mailing_list': ['fryderyk']}])

# %%
get_calendar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6d28241a22e2> in <module>
# ----> 1 get_calendar()
#
# NameError: name 'get_calendar' is not defined

# %%
date('2019-01-01')
